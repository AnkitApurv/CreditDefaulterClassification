# %% [markdown]
# # Outlier Detection

# %% [markdown]
# # 1. Libraries

# %%
#data organizing
import pandas #storage
import numpy as np #data-type conversion
from os import getcwd

#preprocessing
from sklearn.model_selection import train_test_split #to split the data

#outlier/novelty detection
from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest

# %% [markdown]
# # 2. Dataset - Importing

# %%
def cvDefPay(prediction):
    mapper = {0: False, 1: True}
    return mapper.get(prediction)

def cvIsOutlier(prediction):
    mapper = {-1: True, 1: False}
    return mapper.get(prediction)

# %%
url = getcwd() + '\\default of credit card clients.xls'
ccd = pandas.read_excel(io = url, \
                        sheet_name='Data', header = 1, index_col = 0, \
                        dtype = {'LIMIT_BAL': np.int32, 'AGE': np.int32, 'BILL_AMT1': np.int32, 'BILL_AMT2': np.int32, 'BILL_AMT3': np.int32, 'BILL_AMT4': np.int32, 'BILL_AMT5': np.int32, 'BILL_AMT6': np.int32, 'PAY_AMT1': np.int32, 'PAY_AMT2': np.int32, 'PAY_AMT3': np.int32, 'PAY_AMT4': np.int32, 'PAY_AMT5': np.int32, 'PAY_AMT6': np.int32}, \
                        converters = {'default payment next month': cvDefPay})

# %%
ccd.rename(columns = {'PAY_0': 'PAY_1'}, inplace = True)
ccd.rename(columns = {'default payment next month': 'default_payment_next_month'}, inplace = True)

# %% [markdown]
# # 3. Splitting the dataset

# %%
ccdY = pandas.DataFrame(ccd['default_payment_next_month'])
ccdX = ccd.drop(['default_payment_next_month'], axis = 'columns')

# %%
trainX, testX, trainY, testY = train_test_split(ccdX, ccdY, test_size = 0.25, stratify = ccdY, random_state = 44)

# %%
testDF = [testX, testY]
test = pandas.concat(testDF, axis = 'columns')

trainDF = [trainX, trainY]
train = pandas.concat(trainDF, axis = 'columns')

testResult = test.copy(deep = True)

# %% [markdown]
# # 4.a. Outlier Detection: IsolationForest

# %%
isolationForest = IsolationForest(n_estimators = 100, max_samples = 0.2, contamination = 0.00001,
                       n_jobs = -1, random_state = 39)

# %%
isolationForest.fit(train)
# Out:
# IsolationForest(behaviour='deprecated', bootstrap=False, contamination=1e-05,
#                 max_features=1.0, max_samples=0.2, n_estimators=100, n_jobs=-1,
#                 random_state=39, verbose=0, warm_start=False)

# %%
testLabels = isolationForest.predict(test)

# %%
testResult['IsOutlier'] = list(map(cvIsOutlier, testLabels))

# %%
testResult['IsOutlier'].value_counts()
# Out:
# False    7499
# True        1
# Name: IsOutlier, dtype: int64

# %%
testResult['IsOutlier'].value_counts(normalize = True).mul(100).round(2).astype('str') + ' %'
# Out:
# False    99.99 %
# True      0.01 %
# Name: IsOutlier, dtype: object

# %%
test[testResult['IsOutlier'] == True]
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# ID
# 2198    1000000    2          1         1   47      0      0      0     -1
#
#       PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ID           ...
# 2198      0  ...     891586     927171     961664     50784     50723
#
#       PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# ID
# 2198    896040     50000     50000     50256                       False
#
# [1 rows x 24 columns]

# %% [markdown]
# # 4.b. Outlier Detection: OneClassSVM

# %%
oneClassSVM = OneClassSVM(kernel = 'rbf', gamma = 'scale', tol = 0.00001, nu = 0.001, shrinking = True,
                          cache_size = 500, max_iter = -1)

# %%
oneClassSVM.fit(train)
# Out:
# OneClassSVM(cache_size=500, coef0=0.0, degree=3, gamma='scale', kernel='rbf',
#             max_iter=-1, nu=0.001, shrinking=True, tol=1e-05, verbose=False)

# %%
testLabels = oneClassSVM.predict(test)

# %%
testResult['IsOutlier'] = list(map(cvIsOutlier, testLabels))

# %%
testResult['IsOutlier'].value_counts()
# Out:
# False    7465
# True       35
# Name: IsOutlier, dtype: int64

# %%
testResult['IsOutlier'].value_counts(normalize = True).mul(100).round(2).astype('str') + ' %'
# Out:
# False    99.53 %
# True      0.47 %
# Name: IsOutlier, dtype: object

# %%
test[testResult['IsOutlier'] == True]
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# ID
# 29821     400000    1          2         2   37      1     -1      0      0
# 24921     430000    1          1         1   39     -1     -1      0      0
# 2593      480000    1          1         1   49      1     -1     -1     -1
# 5401      500000    2          2         2   49     -1     -1     -1      0
# 28278     260000    2          3         2   49     -2     -2     -2     -2
# 3184      260000    1          3         1   48      0      0      0      0
# 24479     280000    1          1         2   31      2      0      0     -1
# 1262      380000    1          2         1   50      0      0      0      0
# 28716     780000    2          2         2   41     -2     -2     -2     -2
# 20893     550000    1          1         2   35      2      2      2      2
# 29492     320000    1          1         2   31      1     -2     -2     -2
# 7329      330000    2          1         1   40     -2     -2     -2     -1
# 6593      500000    1          1         1   45     -2     -2     -2     -2
# 26215     360000    2          1         2   37     -2     -2     -2     -2
# 14309     500000    2          2         1   40     -2     -2     -2     -2
# 22295     420000    2          2         2   29      0      0     -1      0
# 14333     170000    1          2         2   24      0      0      0      0
# 6151      300000    2          3         2   39      1     -2     -1     -1
# 7415       10000    2          2         2   23      1     -2     -2     -2
# 25732      80000    2          3         1   37      0      0     -2     -2
# 4324      500000    1          2         2   31      2      2      2      0
# 20507     400000    1          1         2   28     -1      0     -1      0
# 19486     280000    2          3         1   46      2      2      0      0
# 26062     240000    2          1         2   29     -2     -2     -2     -2
# 3344      300000    2          2         1   27      0      0      0      0
# 20039     500000    2          2         1   45      0      0      0      0
# 5688      480000    2          1         1   39      0      0     -1      0
# 12331     300000    1          2         1   37      1     -1      2      0
# 3421      420000    2          2         2   29      0      0      0      0
# 20227     200000    2          6         2   51      2      0      0      0
# 2198     1000000    2          1         1   47      0      0      0     -1
# 23759     500000    2          2         1   52      0      0      0      0
# 10618     500000    1          1         1   55      0     -1      0      0
# 13187     750000    2          1         2   28      1     -1     -1      0
# 24389     490000    1          1         1   39      0      0     -1     -1
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ID            ...
# 29821      0  ...     385947     305542     271385    423903     15100
# 24921     -1  ...     325463      38290      21800     50942    325470
# 2593      -1  ...      33146      37337      33777     39149    344261
# 5401       0  ...     391047          0        150      8982    385228
# 28278     -2  ...       2735        316        305    217773    200304
# 3184      -1  ...    -170000     171696     174151      8812      9158
# 24479      0  ...     189841     193313     192742      6996         0
# 1262       0  ...     154283      35270     332270     12020      9009
# 28716     -2  ...      21482      72628     182792     62819     39558
# 20893      2  ...     572805     823540     501370     23000     23000
# 29492     -2  ...     -50616     -53007     -94625       185        28
# 7329      -1  ...      -1878     252686      72401      1800         0
# 6593      -2  ...      38759      46834      28408    261524     43919
# 26215     -2  ...          0          0          0    260416     72200
# 14309     -1  ...      -3772     282777     288937      1093      9429
# 22295     -1  ...       4169     158062     156341      7108     17570
# 14333      0  ...     113576     138419     101452      8092     20121
# 6151      -1  ...       6186        116      14429      1720    344467
# 7415      -2  ...      -1000      -1000      -1000         0         0
# 25732     -2  ...        632        632     124542       215   1024516
# 4324       0  ...     305875      46420      14540      3089     14000
# 20507      0  ...     287499      86684       6796      5056    241366
# 19486      0  ...      54813      38669      18010         0      1803
# 26062     -2  ...      23918     265852       2225     29923      7655
# 3344       0  ...     293063     296677     230338     20000     12003
# 20039      0  ...     112222      33958       9684     14515     10815
# 5688       0  ...      80274      82160     110773    302000     66270
# 12331      0  ...      30355      26771      23737    505000       331
# 3421       0  ...      84732      64614       3068     18000     18691
# 20227      0  ...     425538     419080      98840     10688     10688
# 2198       0  ...     891586     927171     961664     50784     50723
# 23759      0  ...     281810     273700     269552     17559     36500
# 10618      0  ...     207423     197914     188329    226145      7815
# 13187      0  ...     399493     400993     409483    250000    401003
# 24389      0  ...      48409     296319     181627     16405      2324
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# ID
# 29821     14600     13000      9500      9500                       False
# 24921     20003     39068     21800    351282                       False
# 2593      33312     37511     31383     10633                       False
# 5401       7821         0       150       363                       False
# 28278      2759       316       305      2596                       False
# 3184          0    497000     10000      7000                       False
# 24479    189841      6022      6078      5300                        True
# 1262       6109      3000    332000     12000                        True
# 28716     22204     82097    184322     25695                       False
# 20893     18000         0     18373     18159                       False
# 29492        12       208         8        14                        True
# 7329        594    256662      3000      4944                       False
# 6593      38787     46834     28408     63001                       False
# 26215         0         0         0         0                       False
# 14309      3423    291227      9011      9030                       False
# 22295      1000    158556      5000      5080                       False
# 14333    100071     50122      6468    278311                       False
# 6151       6822        49     15000     12000                        True
# 7415          0         0         0      1000                        True
# 25732       632       632    124542     14770                       False
# 4324      14000      1500     14000      2000                       False
# 20507    278006       425        34      2966                       False
# 19486      1475      1105       534       318                        True
# 26062     23925    265852      2225     13478                       False
# 3344      10524     11238      8814      9463                        True
# 20039      5874      2729      9784    279706                       False
# 5688      15000      3044     30042     34048                       False
# 12331      1070     17771     18000     16079                       False
# 3421       5027      3000      3068    175056                       False
# 20227     10278     11567     98843    156961                       False
# 2198     896040     50000     50000     50256                       False
# 23759     20000     36000     20000     80013                       False
# 10618      7372      7113      6967      6261                       False
# 13187      7990     11000    417990      3080                       False
# 24389     25053    280695     17398    160111                       False
#
# [35 rows x 24 columns]
